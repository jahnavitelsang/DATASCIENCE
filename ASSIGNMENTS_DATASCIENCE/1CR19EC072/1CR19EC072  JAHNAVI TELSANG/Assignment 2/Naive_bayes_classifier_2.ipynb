# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('/content/adult.csv')
dataset.head()
# Out:
#    Age          Workclass  random   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  loss  hours_per_week  native_country  income
# 0          2174     0              40   United-States   <=50K
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Workclass', 'random', 'education', 'education_num',
#        'marital_status', 'occupation', 'relationship', 'race', 'sex',
#        'capital_gain', 'loss', 'hours_per_week', 'native_country', 'income'],
#       dtype='object')

# %%
dataset.isnull().sum()
# Out:
# Age               0
# Workclass         0
# random            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# loss              0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %% [markdown]
# ***we get that there is no null value in categorial variables***

# %%
import seaborn as sns
sns.heatmap(dataset.isnull())

# %% [markdown]
# ***Now we will check the frequency distribution of categorial variables***

# %%
dataset.Age.unique()
# Out:
# array([39, 50, 38, 53, 28, 37, 49, 52, 31, 42, 30, 23, 32, 40, 34, 25, 43,
#        54, 35, 59, 56, 19, 20, 45, 22, 48, 21, 24, 57, 44, 41, 29, 18, 47,
#        46, 36, 79, 27, 67, 33, 76, 17, 55, 61, 70, 64, 71, 68, 66, 51, 58,
#        26, 60, 90, 75, 65, 77, 62, 63, 80, 72, 74, 69, 73, 81, 78, 88, 82,
#        83, 84, 85, 86, 87])

# %%
dataset.Age.value_counts()
# Out:
# 36    898
# 31    888
# 34    886
# 23    877
# 35    876
#      ...
# 83      6
# 88      3
# 85      3
# 86      1
# 87      1
# Name: Age, Length: 73, dtype: int64

# %%
dataset.Workclass.unique()
# Out:
# array([' State-gov', ' Self-emp-not-inc', ' Private', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
dataset.Workclass.value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %% [markdown]
# ***we can note down there are 1836 values as '?'***

# %%
dataset['Workclass'].replace('?', np.NaN , inplace=True)

# %%
dataset.Workclass.value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1298
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
dataset.occupation.unique()
# Out:
# array([' Adm-clerical', ' Exec-managerial', ' Handlers-cleaners',
#        ' Prof-specialty', ' Other-service', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
dataset.occupation.value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
dataset['occupation'].replace('?',np.NaN,inplace=True)

# %%
dataset.occupation.value_counts()
# Out:
#  Prof-specialty       4140
#  Craft-repair         4099
#  Exec-managerial      4066
#  Adm-clerical         3770
#  Sales                3650
#  Other-service        3295
#  Machine-op-inspct    2002
#  ?                    1843
#  Transport-moving     1597
#  Handlers-cleaners    1370
#  Farming-fishing       994
#  Tech-support          928
#  Protective-serv       649
#  Priv-house-serv       149
#  Armed-Forces            9
# Name: occupation, dtype: int64

# %%
dataset.native_country.unique()
# Out:
# array([' United-States', ' Cuba', ' Jamaica', ' India', ' ?', ' Mexico',
#        ' South', ' Puerto-Rico', ' Honduras', ' England', ' Canada',
#        ' Germany', ' Iran', ' Philippines', ' Italy', ' Poland',
#        ' Columbia', ' Cambodia', ' Thailand', ' Ecuador', ' Laos',
#        ' Taiwan', ' Haiti', ' Portugal', ' Dominican-Republic',
#        ' El-Salvador', ' France', ' Guatemala', ' China', ' Japan',
#        ' Yugoslavia', ' Peru', ' Outlying-US(Guam-USVI-etc)', ' Scotland',
#        ' Trinadad&Tobago', ' Greece', ' Nicaragua', ' Vietnam', ' Hong',
#        ' Ireland', ' Hungary', ' Holand-Netherlands'], dtype=object)

# %%
dataset.native_country.value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
dataset['native_country'].replace('?',np.NaN,inplace=True)

# %%
dataset.native_country.value_counts()
# Out:
#  United-States                 29170
#  Mexico                          643
#  ?                               583
#  Philippines                     198
#  Germany                         137
#  Canada                          121
#  Puerto-Rico                     114
#  El-Salvador                     106
#  India                           100
#  Cuba                             95
#  England                          90
#  Jamaica                          81
#  South                            80
#  China                            75
#  Italy                            73
#  Dominican-Republic               70
#  Vietnam                          67
#  Guatemala                        64
#  Japan                            62
#  Poland                           60
#  Columbia                         59
#  Taiwan                           51
#  Haiti                            44
#  Iran                             43
#  Portugal                         37
# ...

# %%
sns.pairplot(dataset,hue='income',vars=['capital_gain','hours_per_week','loss','Age','random','education_num'])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['Workclass']=lb.fit_transform(dataset['Workclass'])
dataset['Workclass'].unique()
# Out:
# array([7, 6, 4, 1, 2, 0, 5, 8, 3])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['occupation']=lb.fit_transform(dataset['occupation'])
dataset['occupation'].unique()
# Out:
# array([ 1,  4,  6, 10,  8, 12,  3, 14,  5,  7, 13,  0, 11,  2,  9])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['marital_status']=lb.fit_transform(dataset['marital_status'])
dataset['marital_status'].unique()
# Out:
# array([4, 2, 0, 3, 5, 1, 6])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['education']=lb.fit_transform(dataset['education'])
dataset['education'].unique()
# Out:
# array([ 9, 11,  1, 12,  6, 15,  7,  8,  5, 10, 14,  4,  0,  3, 13,  2])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['relationship']=lb.fit_transform(dataset['relationship'])
dataset['relationship'].unique()
# Out:
# array([1, 0, 5, 3, 4, 2])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['race']=lb.fit_transform(dataset['race'])
dataset['race'].unique()
# Out:
# array([4, 2, 1, 0, 3])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['sex']=lb.fit_transform(dataset['sex'])
dataset['sex'].unique()
# Out:
# array([1, 0])

# %%
from sklearn import preprocessing
lb=preprocessing.LabelEncoder()
dataset['native_country']=lb.fit_transform(dataset['native_country'])
dataset['native_country'].unique()
# Out:
# array([39,  5, 23, 19,  0, 26, 35, 33, 16,  9,  2, 11, 20, 30, 22, 31,  4,
#         1, 37,  7, 25, 36, 14, 32,  6,  8, 10, 13,  3, 24, 41, 29, 28, 34,
#        38, 12, 27, 40, 17, 21, 18, 15])

# %%
  X=dataset.drop(['income'],axis=1)
  y=dataset['income']

# %%
X
# Out:
#        Age  Workclass  random  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32556   27          4  257302          7             12               2
# 32557   40          4  154374         11              9               2
# 32558   58          4  151910         11              9               6
# 32559   22          4  201490         11              9               4
# 32560   52          5  287927         11              9               2
#
#        occupation  relationship  race  sex  capital_gain  loss  \
# ...

# %%
y
# Out:
# 0         <=50K
# 1         <=50K
# 2         <=50K
# 3         <=50K
# 4         <=50K
#           ...
# 32556     <=50K
# 32557      >50K
# 32558     <=50K
# 32559     <=50K
# 32560      >50K
# Name: income, Length: 32561, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
X_train
# Out:
#        Age  Workclass  random  education  education_num  marital_status  \
# 16525   44          5   64632         10             16               2
# 14551   22          4  211361          9             13               4
# 518     21          0  204226         15             10               4
# 22524   46          4  330416         15             10               2
# 11425   17          4  226717          2              8               4
# ...    ...        ...     ...        ...            ...             ...
# 32511   25          2  514716          9             13               4
# 5192    32          4  207668          9             13               2
# 12172   27          4  104457          9             13               4
# 235     59          7  268700         11              9               2
# 29733   33          4   59083          9             13               2
#
#        occupation  relationship  race  sex  capital_gain  loss  \
# ...

# %%
y_test
# Out:
# 9646      <=50K
# 709       <=50K
# 7385       >50K
# 16671     <=50K
# 21932     <=50K
#           ...
# 29663      >50K
# 29310     <=50K
# 29661     <=50K
# 19491     <=50K
# 2861      <=50K
# Name: income, Length: 9769, dtype: object

# %%
from sklearn.preprocessing import StandardScaler 
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB 
classifier=GaussianNB()
classifier.fit(X_train,y_train)
y_pred=classifier.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix 
cm=confusion_matrix(y_test,y_pred)
ac=accuracy_score(y_test,y_pred)

# %%
cm
# Out:
# array([[7176,  374],
#        [1481,  738]])

# %%
ac
# Out:
# 0.8101136247312929

# %%
from sklearn.svm import SVC 
ab=SVC()
ab.fit(X_train,y_train)
y_pred1=ab.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix 
cm1=confusion_matrix(y_test,y_pred1)
ac1=accuracy_score(y_test,y_pred1)

# %%
cm1
# Out:
# array([[7111,  439],
#        [ 998, 1221]])

# %%
ac1
# Out:
# 0.8529020370559934
