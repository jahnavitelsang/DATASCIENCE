# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavitelsang/DATASCIENCE/blob/main/PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PYTHON**

# %% [markdown]
# # **INPUT FUNCTION**

# %%
variable = input()

# %%
name = input("enter the name : ")
print(name)
print("hello", name)

# %%
age = input("enter the age :")
print("the age is ", age)
type(age)

# %%
age = int(input("enter the age :"))
print("the age is ", age)
type(age)

# %%
age = float(input("enter the age :"))
print("the age is ", age)
type(age)

# %%
temp = float(input("enter the temp :"))
print("the temp is ", age)
type(age)

# %% [markdown]
# # **DATA STRUCTURES**

# %% [markdown]
# # **LISTS------- pass all data types**

# %%
l1 = [17,89,18,78]  #int#
l2 = [4.7,9.0,4.5]   #float#
l3 = ['hello',1,3.89,True]  #mixed#
print(l1,l2,l3)

# %%
l4 = []
print(l4)

# %% [markdown]
# # **INDEXING**

# %%
lt1 = [2,4,5,6,7,8]
lt1[0]
print(lt1[0])
print(lt1[5])

# %%
lt1 = [2,4,5,6,7,8]
lt1[-1]
print(lt1[-1])
print(lt1[-3])

# %% [markdown]
# # **MUTUABLE**

# %% [markdown]
# ## **IF IDS ARE SAME THEN MUTUABLE** ---- id1=id2

# %%
l = [1,3,4,5,6,7,'apple']
print(id(l))

# %%
l[1] = 'banana'
l[-3] = True
print(l)
id(l)

# %%
p = [1,2,3,4]
print(id(p))

# %%
p[0]= True
print(p)
id(p)

# %% [markdown]
# # **ALLOWS DUPLICATE**

# %% [markdown]
# # **ALLOWS MIXED DATATYPES AS WELL**

# %%
name = [1,5.6,True,[1,1,1,1,1]]
print(name)

# %% [markdown]
# # **LIST METHODS**

# %%
a = [2,3,4]
a

# %% [markdown]
# # **ADDING**

# %%
a.append(90)
a

# %%
a.insert(2,'orange')
a

# %%
b = [1,3,4,'janu']
a.extend(b)
a

# %% [markdown]
# # REMOVING

# %%
a = [2, 3, 'orange', 4, 90, 1, 3, 4, 'janu']
a.remove(3)
a

# %%
a.pop() #removes and returns the last value#

# %%
a.pop(4)    #removes and returns vale in pop#

# %%
a.clear()
a

# %% [markdown]
# # OTHERS

# %%
b = [2,3,4,5,6,7]
len(b)

# %%
b.index(3)

# %%
c = [3,3,3,5,8,9,0,4,5]
c.count(5)

# %%
c.sort()
c

# %%
c.reverse()
c

# %%
#looping#
janu = ['mom','dad','brother']
for i in janu:
  print(i)

# %% [markdown]
# # **CHECKING THE MEMBERSHIP**

# %%
colors = ['red','blue','green']
print('blue'in colors)
print('white'in colors)
print('purple'not in colors)

# %% [markdown]
# # **list slicing**

# %%
num = ['a','b','c','d','e','f','g']
num

# %%
num[:]

# %%
num[::]

# %%
num[:5:]

# %%
num[::-1]

# %%
num[5::]

# %%
num[::3]

# %%
num[-1:-4:-2]

# %%
num[-3:-1]

# %% [markdown]
# # **TUPLE**

# %%
t1 = ('apple',5.76,78,False)
t1

# %%
type(t1)

# %%
t2 = (1,2,3)
t2
type(t2)

# %%
t3 = (1)
t3
type(t3)

# %% [markdown]
# # **ALWAYS USE COMMA WHEN USING SINGLE DIGIT AS TUPLE**

# %%
t4 = (7,)
t4
type(t4)

# %% [markdown]
# PACKING AND UNPACKING

# %%
a = 26
b = 90
t = (a,b)
print(t)

# %%
x,y = t
print(x)
print(y)

# %%
v = (7,8,9)
print(len(v))   # functionsssssssssssssssssssssssssssssssssssssssssss#
print(sum(v))
print(min(v))
print(max(v))

# %% [markdown]
# # **LIST INSIDE THE TUPLE IS MUTUABLE AND CAN BE CHANGED**

# %%
w = (2,3,[6,7])
w[2][1] = 78
w

# %% [markdown]
# ACCESSING AND SLICLING OF TUPLE
# # **Cannot be modified but can be accessed**

# %%
w[0]

# %%
f = (1,2,3,4)
f[0]

# %%
f[::-1]

# %%
f[1::]

# %%
f[:2:]

# %%
f[::2]

# %%
f[3:4:]

# %% [markdown]
# # **TUPLE OPERATION**
# CONCATATION
# REPETATION
# MEMBERSHIP

# %%
e = ('v','o','p')  #concatation#
h = (3,4,5)
print(e+h)

# %%
print(('e',)*3)  #repetation#

# %%
print(3 in (4,5,6)) #membership3

# %% [markdown]
# # **TUPLE HAS 2 MAIN METHODS THAT IS COUNT AND INDEX**

# %% [markdown]
# # **CONVERT THE TUPLE TO LIST AND THEN MODIFY AND THEN CONVERY BACK TO TUPLE**

# %%
a = (1,2,3,4)
a

# %%
temp = list(a)
temp

# %%
temp.append(5)
temp

# %%
tuple(temp)

# %% [markdown]
# ## **SET**

# %%
s = {1,2,3,4}
s1 = {1,1,1,2,3,4,4,4,5,56}
s
s1

# %%
s2 = {1,2.3,'python',False,(1,2,3,4)}
s2

# %%
s3 = set([1,2,3,4])  #creating a set using set constructor#
s3

# %%
s4 = set('hello')  # because of this there is no indexinga nd slicing bze it is unordered#
s4

# %%
s5 = {}#                       always get a set through set constructor#
s5

# %%
type(s5)

# %%
s6 = set()
s6

# %%
type(s6)

# %% [markdown]
# # **SET METHODS**

# %%
s = {'apple', 'banana', 'cherry'}
s

# %%
s.add('mango')
s

# %%
s.add('apple')   #no duplicate allowed#
s

# %%
s.update(['cheeku','orange'])
s

# %%
s.remove('cheeku')
s

# %%
s.remove('grape')
s

# %%
s.discard('grape')       # best to use discard for set bze no errors#
s

# %%
s.clear()
s

# %% [markdown]
# ## **SET OPEREATIONS **

# %%
k1 = {1,2,3,4}
k2 = {3,4,5,6,7}
o = k1.union(k2)
o

# %%
o1 = k1.intersection(k2)
o1

# %%
o3 = k1.difference(k2)
o3

# %%
o4 = k2.difference(k1)
o4

# %%
o5 = k1.symmetric_difference(k2)
o5

# %% [markdown]
# # **DICTIONARY**

# %%
d = {'name':'janu', 'age':25}
d

# %% [markdown]
# Creating a dict in multiple ways

# %%
d1 = {}
d1

# %%
d2 = dict()
d2

# %%
d3 = dict(name='jane',age=25)
d3

# %%
d4 = dict([('name','jane'),('age',25)])    # CREATING A LIST OF TUPLES#
d4

# %% [markdown]
# MUTUALIBILITY IN DICT

# %%
i = {'name':'jane', 'city':'belgaum'}
i

# %%
id(i)

# %%
i['city'] = 'bangalore'
i

# %%
id(i)          #ID1===ID2#

# %%
s = {'name':'alice'}
s['name'] = 'jane'
s['age'] = 25
s

# %%
s.update({'name':'janu', 'age':22, 'grade':'a'})
s

# %% [markdown]
# # **ACCESSING**

# %%
s3 = {'name':'jane','grade':'a'}
s3

# %%
s3['name']

# %%
s3['city']

# %%
s3.get('grade')

# %%
s3.get('city')

# %% [markdown]
# # **BUILTIN FUNS**

# %%
s4 = {'name':'jane','grade':'a'}
s4

# %%
print(s4.keys())

# %%
print(s4.values())

# %%
print(s4.items())

# %% [markdown]
# # **POP FUNCTION** --------- pop removes the key which is passes and popitem removes the last item by default

# %%
s = {'name':'jane','grade':'a','course':'ds'}

# %%
s

# %%
s.pop('name')
s

# %%
s.popitem()
s

# %% [markdown]
# # **dict comprensation**

# %%
d = {x:x**2  for x in range(1,6)}
d

# %%
school = {
    'student' :{'name':"jane", 'class':12},
    'student1' : {'name':'janu','class':11}
}
school                                                                                  # NESTED DICT #

# %%
print(school['student']['class'])

# %%
age = int(input('enter the age:'))
if age >= 18:
  print('adult')
else:
  print('minor')

# %%
for i in range(10):
  print(i)

# %%
num = 0
while num < 5 :
  print(num)
  num += 1
num

# %%
def square(num):
  return num*num

print(square(4))

# %% [markdown]
# # **NUMPY AND PANDAS**

# %% [markdown]
# NUMPY

# %%
import numpy as np

# %%
sum = np.array([12,23,34,45,67,78])   # 1D array#
sum
# Out:
# array([12, 23, 34, 45, 67, 78])

# %%
sum.shape
# Out:
# (6,)

# %%
sum1 = np.array([[12],[89],[45],[56]])     #2D array#
sum1
# Out:
# array([[12],
#        [89],
#        [45],
#        [56]])

# %%
sum1.shape
# Out:
# (4, 1)

# %%
data = np.array([[12,23,23,34],[67,64,31,23],[637,84,920,84],[97,342,26,68]])
data
# Out:
# array([[ 12,  23,  23,  34],
#        [ 67,  64,  31,  23],
#        [637,  84, 920,  84],
#        [ 97, 342,  26,  68]])

# %%
data.shape
# Out:
# (4, 4)

# %%
sp = data[:,0:1]
sp
# Out:
# array([[ 12],
#        [ 67],
#        [637],
#        [ 97]])

# %%
print(np.mean(data[:,0:1]))
# Out:
# 203.25

# %%
print(np.median(data[:,0:1]))
# Out:
# 82.0

# %%
print(np.std(data[:,0:1]))
# Out:
# 252.27403255190575

# %%
print(np.var(data[:,0:1]))
# Out:
# 63642.1875

# %%
print(sp.mean())
# Out:
# 203.25

# %%
print(data[:,0:2])
# Out:
# [[ 12  23]
#  [ 67  64]
#  [637  84]
#  [ 97 342]]

# %%
print(data[:,0:3:2])
# Out:
# [[ 12  23]
#  [ 67  31]
#  [637 920]
#  [ 97  26]]

# %% [markdown]
# CREATING RANDOM NUMBERS IN 1D

# %%
x = np.random.randint(10,20,size=10)
x
# Out:
# array([14, 13, 11, 17, 11, 14, 19, 13, 13, 17])

# %%
x.ndim
# Out:
# 1

# %%
x1 = np.random.randint(10,20,size=(2,3))
x1
# Out:
# array([[16, 13, 13],
#        [10, 19, 10]])

# %%
x1.ndim
# Out:
# 2

# %%
x4 = np.random.randint(10,20,size=(3,3,4))
x4
# Out:
# array([[[13, 16, 11, 12],
#         [17, 11, 16, 18],
#         [13, 14, 16, 12]],
#
#        [[16, 17, 11, 14],
#         [13, 16, 18, 17],
#         [17, 19, 16, 16]],
#
#        [[16, 19, 18, 14],
#         [19, 11, 18, 10],
#         [18, 18, 19, 12]]])

# %%
x4.ndim
# Out:
# 3

# %%
import pandas as pd

# %%
a = [1,2,3,4,5]
s = pd.Series(a)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# dataframe=====2d array table in the form of rows and colimns

# %%
a = pd.DataFrame([[1,2,3],[4,5,6],[7,8,9]])
print(a)
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
df = pd.read_csv("/content/nyc_Jan_Jun_2016_weat.csv")

# %%
df.head()
# Out:
#        DATE  LATITUDE  LONGITUDE  SNOW  PRCP    SNWD  TAVG  TMAX  TMIN
# 0  20160101   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 1  20160102   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 2  20160103   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 3  20160104   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 4  20160105   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999

# %%
df.shape
# Out:
# (32207, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32207 entries, 0 to 32206
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   DATE       32207 non-null  int64
#  1   LATITUDE   32207 non-null  float64
#  2   LONGITUDE  32207 non-null  float64
#  3   SNOW       32207 non-null  float64
#  4   PRCP       32207 non-null  float64
#  5   SNWD       32207 non-null  float64
#  6   TAVG       32207 non-null  int64
#  7   TMAX       32207 non-null  int64
#  8   TMIN       32207 non-null  int64
# dtypes: float64(5), int64(4)
# memory usage: 2.2 MB

# %%
df.describe()
# Out:
#                DATE      LATITUDE     LONGITUDE          SNOW          PRCP  \
# count  3.220700e+04  32207.000000  32207.000000  32207.000000  32207.000000
# mean   2.016379e+07     40.758364    -74.115480  -4263.479085    -41.474001
# std    4.553580e+03      0.210378      0.250133   4945.177190    643.636786
# min    2.016010e+07     40.275400    -74.482700  -9999.000000  -9999.000000
# 25%    2.016051e+07     40.662300    -74.284700  -9999.000000      0.000000
# 50%    2.016092e+07     40.755600    -74.152300      0.000000      0.000000
# 75%    2.017021e+07     40.902700    -74.000200      0.000000      0.070000
# max    2.017072e+07     41.083500    -73.372200     68.000000     17.760000
#
#                SNWD          TAVG          TMAX          TMIN
# count  32207.000000  32207.000000  32207.000000  32207.000000
# mean   -7452.434185  -9472.630453  -7806.498743  -7798.696184
# std     4356.649666   2239.591076   4153.806872   4154.587650
# ...

# %%
df['LATITUDE'].head()
# Out:
# 0    41.0639
# 1    41.0639
# 2    41.0639
# 3    41.0639
# 4    41.0639
# Name: LATITUDE, dtype: float64

# %%
df[['LONGITUDE','PRCP']].head()
# Out:
#    LONGITUDE  PRCP
# 0   -73.7722   0.0
# 1   -73.7722   0.0
# 2   -73.7722   0.0
# 3   -73.7722   0.0
# 4   -73.7722   0.0

# %% [markdown]
# LOC AND ILOC CONCEPT

# %%
df.loc[0:4,['LONGITUDE','PRCP	']]  #          using the lables as well #
# Out:
#    LONGITUDE  PRCP
# 0   -73.7722   0.0
# 1   -73.7722   0.0
# 2   -73.7722   0.0
# 3   -73.7722   0.0
# 4   -73.7722   0.0

# %%
df.loc[[0,4,7],['LONGITUDE','PRCP']]
# Out:
#    LONGITUDE  PRCP
# 0   -73.7722   0.0
# 4   -73.7722   0.0
# 7   -73.7722   0.0

# %%
df.loc[0:6,'LONGITUDE':'SNWD']
# Out:
#    LONGITUDE  SNOW  PRCP    SNWD
# 0   -73.7722   0.0   0.0 -9999.0
# 1   -73.7722   0.0   0.0 -9999.0
# 2   -73.7722   0.0   0.0 -9999.0
# 3   -73.7722   0.0   0.0 -9999.0
# 4   -73.7722   0.0   0.0 -9999.0
# 5   -73.7722   0.0   0.0 -9999.0
# 6   -73.7722   0.0   0.0 -9999.0

# %%
df.iloc[:,0:5].head()             # using only the intergers that is by rows and columns#
# Out:
#        DATE  LATITUDE  LONGITUDE  SNOW  PRCP
# 0  20160101   41.0639   -73.7722   0.0   0.0
# 1  20160102   41.0639   -73.7722   0.0   0.0
# 2  20160103   41.0639   -73.7722   0.0   0.0
# 3  20160104   41.0639   -73.7722   0.0   0.0
# 4  20160105   41.0639   -73.7722   0.0   0.0

# %%
df.iloc[0:8,2:5]
# Out:
#    LONGITUDE  SNOW  PRCP
# 0   -73.7722   0.0   0.0
# 1   -73.7722   0.0   0.0
# 2   -73.7722   0.0   0.0
# 3   -73.7722   0.0   0.0
# 4   -73.7722   0.0   0.0
# 5   -73.7722   0.0   0.0
# 6   -73.7722   0.0   0.0
# 7   -73.7722   0.0   0.0

# %%
df.iloc[2:15,[1,6,8]]
# Out:
#     LATITUDE  TAVG  TMIN
# 2    41.0639 -9999 -9999
# 3    41.0639 -9999 -9999
# 4    41.0639 -9999 -9999
# 5    41.0639 -9999 -9999
# 6    41.0639 -9999 -9999
# 7    41.0639 -9999 -9999
# 8    41.0639 -9999 -9999
# 9    41.0639 -9999 -9999
# 10   41.0639 -9999 -9999
# 11   41.0639 -9999 -9999
# 12   41.0639 -9999 -9999
# 13   41.0639 -9999 -9999
# 14   41.0639 -9999 -9999

# %%
df.iloc[[1,2,4,5],4:8]
# Out:
#    PRCP    SNWD  TAVG  TMAX
# 1   0.0 -9999.0 -9999 -9999
# 2   0.0 -9999.0 -9999 -9999
# 4   0.0 -9999.0 -9999 -9999
# 5   0.0 -9999.0 -9999 -9999

# %%
df[df['TMAX']>100].head()
# Out:
#           DATE  LATITUDE  LONGITUDE  SNOW  PRCP  SNWD  TAVG  TMAX  TMIN
# 4938  20170613   40.7792     -73.88   0.0   0.0   0.0    90   101    80

# %%
df[df['PRCP']<100].head()
# Out:
#        DATE  LATITUDE  LONGITUDE  SNOW  PRCP    SNWD  TAVG  TMAX  TMIN
# 0  20160101   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 1  20160102   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 2  20160103   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 3  20160104   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 4  20160105   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999

# %%
df[df['TAVG'] == -9999].head()
# Out:
#        DATE  LATITUDE  LONGITUDE  SNOW  PRCP    SNWD  TAVG  TMAX  TMIN
# 0  20160101   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 1  20160102   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 2  20160103   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 3  20160104   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 4  20160105   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999

# %%
df.sort_values(by='TAVG').head()   # for ascending sorting #
# Out:
#            DATE  LATITUDE  LONGITUDE  SNOW  PRCP    SNWD  TAVG  TMAX  TMIN
# 21653  20170709   40.4562   -74.2413   0.0   0.0 -9999.0 -9999 -9999 -9999
# 21668  20160109   40.6670   -74.4827   0.0   0.0 -9999.0 -9999 -9999 -9999
# 21667  20160108   40.6670   -74.4827   0.0   0.0 -9999.0 -9999 -9999 -9999
# 21666  20160107   40.6670   -74.4827   0.0   0.0 -9999.0 -9999 -9999 -9999
# 21665  20160106   40.6670   -74.4827   0.0   0.0 -9999.0 -9999 -9999 -9999

# %%
df.sort_values(by='TAVG',ascending=False).head()
# Out:
#           DATE  LATITUDE  LONGITUDE  SNOW  PRCP  SNWD  TAVG  TMAX  TMIN
# 4635  20160814   40.7792   -73.8800   0.0  0.01   0.0    91    98    81
# 4938  20170613   40.7792   -73.8800   0.0  0.00   0.0    90   101    80
# 4613  20160723   40.7792   -73.8800   0.0  0.00   0.0    89    99    82
# 4634  20160813   40.7792   -73.8800   0.0  0.00   0.0    89    98    84
# 6092  20160814   40.6825   -74.1694   0.0  0.00   0.0    89    97    80

# %%
df.isnull()
# Out:
#         DATE  LATITUDE  LONGITUDE   SNOW   PRCP   SNWD   TAVG   TMAX   TMIN
# 0      False     False      False  False  False  False  False  False  False
# 1      False     False      False  False  False  False  False  False  False
# 2      False     False      False  False  False  False  False  False  False
# 3      False     False      False  False  False  False  False  False  False
# 4      False     False      False  False  False  False  False  False  False
# ...      ...       ...        ...    ...    ...    ...    ...    ...    ...
# 32202  False     False      False  False  False  False  False  False  False
# 32203  False     False      False  False  False  False  False  False  False
# 32204  False     False      False  False  False  False  False  False  False
# 32205  False     False      False  False  False  False  False  False  False
# 32206  False     False      False  False  False  False  False  False  False
#
# [32207 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# DATE         0
# LATITUDE     0
# LONGITUDE    0
# SNOW         0
# PRCP         0
# SNWD         0
# TAVG         0
# TMAX         0
# TMIN         0
# dtype: int64

# %%
df.dropna().head()        #dropping null values#
# Out:
#        DATE  LATITUDE  LONGITUDE  SNOW  PRCP    SNWD  TAVG  TMAX  TMIN
# 0  20160101   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 1  20160102   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 2  20160103   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 3  20160104   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999
# 4  20160105   41.0639   -73.7722   0.0   0.0 -9999.0 -9999 -9999 -9999

# %%
df.fillna(0)
# Out:
#            DATE  LATITUDE  LONGITUDE    SNOW  PRCP    SNWD  TAVG  TMAX  TMIN
# 0      20160101  41.06390  -73.77220     0.0  0.00 -9999.0 -9999 -9999 -9999
# 1      20160102  41.06390  -73.77220     0.0  0.00 -9999.0 -9999 -9999 -9999
# 2      20160103  41.06390  -73.77220     0.0  0.00 -9999.0 -9999 -9999 -9999
# 3      20160104  41.06390  -73.77220     0.0  0.00 -9999.0 -9999 -9999 -9999
# 4      20160105  41.06390  -73.77220     0.0  0.00 -9999.0 -9999 -9999 -9999
# ...         ...       ...        ...     ...   ...     ...   ...   ...   ...
# 32202  20170709  40.73417  -73.41694 -9999.0  0.00 -9999.0 -9999    82    67
# 32203  20170710  40.73417  -73.41694 -9999.0  0.00 -9999.0 -9999    81    64
# 32204  20170711  40.73417  -73.41694 -9999.0  0.06 -9999.0 -9999    86    74
# 32205  20170712  40.73417  -73.41694 -9999.0  0.00 -9999.0 -9999    90    74
# 32206  20170713  40.73417  -73.41694 -9999.0  0.01 -9999.0 -9999    91    68
#
# [32207 rows x 9 columns]

# %% [markdown]
# # **GROUPING**

# %%
df.groupby('TMAX')['TMIN'].mean()
# Out:
# TMAX
# -9999   -9979.048037
#  12        -2.000000
#  13        -3.000000
#  14        -3.000000
#  15        -1.000000
#             ...
#  97        74.875000
#  98        76.727273
#  99        73.400000
#  100       77.500000
#  101       80.000000
# Name: TMIN, Length: 91, dtype: float64

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/market.csv')

# %%
df.head()
# Out:
#    Region       Product   Subsidiary  Stores  Sales  Inventory  Returns
# 0  Africa          Boot  Addis Ababa      12  29761     191821      769
# 1  Africa  Men's Casual  Addis Ababa       4  67242     118036     2284
# 2  Africa   Men's Dress  Addis Ababa       7  76793     136273     2433
# 3  Africa        Sandal  Addis Ababa      10  62819     204284     1861
# 4  Africa       Slipper  Addis Ababa      14  68641     279795     1771

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 390 entries, 0 to 389
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Region      390 non-null    object
#  1   Product     390 non-null    object
#  2   Subsidiary  390 non-null    object
#  3   Stores      390 non-null    int64
#  4   Sales       390 non-null    int64
#  5   Inventory   390 non-null    int64
#  6   Returns     390 non-null    int64
# dtypes: int64(4), object(3)
# memory usage: 21.5+ KB

# %%
df.describe()
# Out:
#            Stores          Sales     Inventory       Returns
# count  390.000000     390.000000  3.900000e+02    390.000000
# mean    11.502564   76313.023077  2.261371e+05   2659.658974
# std      8.804868   95418.194363  2.679502e+05   3323.966711
# min      1.000000     325.000000  3.740000e+02     10.000000
# 25%      3.000000   15124.500000  4.264050e+04    575.000000
# 50%     10.000000   38005.500000  1.181490e+05   1407.000000
# 75%     17.000000  104344.750000  3.280922e+05   3438.500000
# max     41.000000  502636.000000  1.555357e+06  20470.000000

# %%
df.shape
# Out:
# (390, 7)

# %%
df.groupby('Region')['Sales'].sum()     # to get the region wise sales#
# Out:
# Region
# Africa                       2342588
# Asia                          460231
# Canada                       2041054
# Central America/Caribbean    3081641
# Eastern Europe               2394940
# Middle East                  4333062
# Pacific                      2296794
# South America                2434783
# United States                5503986
# Western Europe               4873000
# Name: Sales, dtype: int64

# %%
df.groupby('Product')['Inventory'].sum()       # to get the how many are there in a product #
# Out:
# Product
# Boot               9724671
# Men's Casual      13044692
# Men's Dress       12659781
# Sandal             3232275
# Slipper           19711295
# Sport Shoe         3322702
# Women's Casual     9696651
# Women's Dress     16801392
# Name: Inventory, dtype: int64

# %%
df.groupby('Region')['Sales'].mean()
# Out:
# Region
# Africa                        41831.928571
# Asia                          32873.642857
# Canada                        60031.000000
# Central America/Caribbean     99407.774194
# Eastern Europe                77256.129032
# Middle East                  188394.000000
# Pacific                       51039.866667
# South America                 45088.574074
# United States                137599.650000
# Western Europe                78596.774194
# Name: Sales, dtype: float64

# %%
df.groupby(['Region','Product'])['Sales'].sum()
# Out:
# Region          Product
# Africa          Boot              119835
#                 Men's Casual      562794
#                 Men's Dress       318500
#                 Sandal            190409
#                 Slipper           337076
#                                    ...
# Western Europe  Sandal             11349
#                 Slipper           857298
#                 Sport Shoe        201030
#                 Women's Casual    985647
#                 Women's Dress     827479
# Name: Sales, Length: 80, dtype: int64

# %%
df.groupby(['Region','Stores'])['Sales'].mean()
# Out:
# Region          Stores
# Africa          1          12759.800000
#                 2          27308.000000
#                 3          26457.166667
#                 4          43705.000000
#                 5          26962.666667
#                               ...
# Western Europe  23         88216.500000
#                 25        149354.000000
#                 26        502636.000000
#                 27        109808.000000
#                 31         54449.000000
# Name: Sales, Length: 194, dtype: float64

# %%
df[df['Region'] == 'Africa'].head()
# Out:
#    Region       Product   Subsidiary  Stores  Sales  Inventory  Returns
# 0  Africa          Boot  Addis Ababa      12  29761     191821      769
# 1  Africa  Men's Casual  Addis Ababa       4  67242     118036     2284
# 2  Africa   Men's Dress  Addis Ababa       7  76793     136273     2433
# 3  Africa        Sandal  Addis Ababa      10  62819     204284     1861
# 4  Africa       Slipper  Addis Ababa      14  68641     279795     1771

# %%
df[df['Region'] != 'Africa'].head()
# Out:
#    Region         Product Subsidiary  Stores  Sales  Inventory  Returns
# 56   Asia            Boot    Bangkok       1   1996       9576       80
# 57   Asia     Men's Dress    Bangkok       1   3033      20831       52
# 58   Asia          Sandal    Bangkok       1   3230      15087      120
# 59   Asia         Slipper    Bangkok       1   3019      16075      127
# 60   Asia  Women's Casual    Bangkok       1   5389      16251      185
