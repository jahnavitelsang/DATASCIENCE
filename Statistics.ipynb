# %% [markdown]
# <a href="https://colab.research.google.com/github/jahnavitelsang/DATASCIENCE/blob/main/Statistics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***STATISTICS***

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("/content/diabetes.csv")

# %% [markdown]
# IT GIVES THE HEAD COUNT UPTO 5

# %%
df.head(10)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
# 5            5      116             74              0        0  25.6
# 6            3       78             50             32       88  31.0
# 7           10      115              0              0        0  35.3
# 8            2      197             70             45      543  30.5
# 9            8      125             96              0        0   0.0
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# ...

# %% [markdown]
# SHAPE function gives the number of column and row . Doesnt include the bracket as there is no number to be added in

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# PROVIDES THE INFORMATION ABOUT THE DATA SET
# MEANING: INFORMATION ABOUT THE NON NULL VALUES

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# DESCRIBE FUNCTION DESCRIBES THE AVG, HIGHEST LOWEST ETC ETC

# %% [markdown]
# info() function → tells you what data is available and whether anything is missing.
#
# describe() function → tells you a summary of the values in the data (like average, smallest, largest, etc.).

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %% [markdown]
# # **NOW LETS GET THE MEAN MEDIAN MODE, by df[].mean() function**

# %% [markdown]
# MEAN AND MEDIAN-------------NUMERIC
# # MODE------------------------NUMERIC AND *CATEGORICAL **bold text**

# %%
print(df['BloodPressure'].mean())
# Out:
# 69.10546875

# %%
print(df['BMI'].mean())
# Out:
# 31.992578124999998

# %%
df['Insulin'].median()
# Out:
# 30.5

# %%
df['SkinThickness'].mode()
# Out:
# 0    0
# Name: SkinThickness, dtype: int64

# %% [markdown]
# # **THE BELOW FUCTION Only use number columns and ignore text columns.”**

# %%
df.mean(numeric_only=True)
# Out:
# Pregnancies                   3.845052
# Glucose                     120.894531
# BloodPressure                69.105469
# SkinThickness                20.536458
# Insulin                      79.799479
# BMI                          31.992578
# DiabetesPedigreeFunction      0.471876
# Age                          33.240885
# Outcome                       0.348958
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Pregnancies                   3.0000
# Glucose                     117.0000
# BloodPressure                72.0000
# SkinThickness                23.0000
# Insulin                      30.5000
# BMI                          32.0000
# DiabetesPedigreeFunction      0.3725
# Age                          29.0000
# Outcome                       0.0000
# dtype: float64

# %%
df.mode()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0          1.0       99           70.0            0.0      0.0  32.0
# 1          NaN      100            NaN            NaN      NaN   NaN
#
#    DiabetesPedigreeFunction   Age  Outcome
# 0                     0.254  22.0      0.0
# 1                     0.258   NaN      NaN

# %% [markdown]
# # **TO VISUALIZE THE DATA**, helps us turn data into visual graphs or charts

# %%
import matplotlib.pyplot as pyt

# %% [markdown]
# df.hist(figsize=(10,12))------hist is histogram and figsize is the size of the graph
# # **plt.show()------ disply the graph**

# %%
df.hist(figsize=(14,12))
pyt.show()

# %% [markdown]
# # **counts how many times each glucose value or category appears in the glucose column.**

# %%
df['Age'].value_counts()
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 36    16
# 38    16
# 32    16
# 45    15
# 34    14
# 46    13
# 40    13
# 43    13
# 39    12
# 35    10
# 44     8
# 50     8
# 51     8
# 52     8
# 58     7
# 54     6
# 47     6
# 49     5
# 60     5
# 53     5
# 57     5
# 48     5
# 63     4
# 66     4
# 55     4
# 62     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 72     1
# 81     1
# 64     1
# 70     1
# 68     1
# Name: count, dtype: int64

# %% [markdown]
# # **kind='bar' tells Python:  “Use bars (rectangles) to display the counts.”**

# %%
df['Age'].value_counts().plot(kind="bar")
pyt.show()

# %% [markdown]
# GENERALLY BOX PLOT FOR ALL THE DATA

# %%
df.boxplot()
pyt.show()

# %% [markdown]
# SCATTER PLOT-----plt.scatter(df['Age'], df['BMI'])
#
# # **This creates a scatter plot (a graph made of dots).**

# %%
pyt.scatter(df['Age'],df['BMI'])
pyt.xlabel("Age")
pyt.ylabel("BMI")
pyt.show()
